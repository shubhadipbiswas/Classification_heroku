# %%
import pandas as pd

# %%
classify = pd.read_csv('https://raw.githubusercontent.com/shubhadipbiswas/Classification_heroku/master/Booking_Classification.csv')

# %%
classify.head()
# Out:
#      Hotel_Type  Unnamed: 1  lead_time  Date_Year Date_Month  Year_Week  \
# 0  Resort Hotel         NaN        342       2015       July         27
# 1  Resort Hotel         NaN        737       2015       July         27
# 2  Resort Hotel         NaN          7       2015       July         27
# 3  Resort Hotel         NaN         13       2015       July         27
# 4  Resort Hotel         NaN         14       2015       July         27
#
#    Day_Of_Month  Weekend_Stay?  stays_in_week_nights  Count_Pax  ...  agent  \
# 0             1              0                     0          2  ...    NaN
# 1             1              0                     0          2  ...    NaN
# 2             1              0                     1          1  ...    NaN
# 3             1              0                     1          1  ...  304.0
# 4             1              0                     2          2  ...  240.0
#
#    company days_in_waiting_list customer_type   adr  \
# 0      NaN                    0     Transient   0.0
# 1      NaN                    0     Transient   0.0
# 2      NaN                    0     Transient  75.0
# 3      NaN                    0     Transient  75.0
# 4      NaN                    0     Transient  98.0
#
#   required_car_parking_spaces  total_of_special_requests  reservation_status  \
# 0                           0                          0           Check-Out
# 1                           0                          0           Check-Out
# 2                           0                          0           Check-Out
# 3                           0                          0           Check-Out
# 4                           0                          1           Check-Out
#
#    reservation_status_date Booking_Cancelled
# 0               01-07-2015                 0
# 1               01-07-2015                 0
# 2               02-07-2015                 0
# 3               02-07-2015                 0
# 4               03-07-2015                 0
#
# [5 rows x 33 columns]
